# %% [markdown]
# <a href="https://colab.research.google.com/github/IshwariDole/Machine-Learning/blob/main/Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.mlab as mlb

# %%
a=pd.read_csv("/content/1709018943631_1709018913702_1. Simple linear regression (1).csv")
a.head()
x=a.SAT
y=a.GPA

# %%
plt.title("Line of regrassion")
plt.xlabel("SAT")
plt.ylabel("GPA")
plt.scatter(x,y)
#plt.show()
b0=0.2750
b1=0.0017
y_hat=b0+b1*x
plt.plot(x, y_hat, c="red")
